# %% [markdown]
# ## The MatPlotLib Architecture

# %% [markdown]
# Examine the current architecture at a high level using the metaphores put forth by the core developers of matplotlib
#
# Dive into the details of the three major layers of the matplotlib architecture

# %% [markdown]
# ### Primary Layers

# %% [markdown]
# ![matplotlib_basicArchitecture.png](data:image/png;base64,...)

# %% [markdown]
# #### Backend Layer

# %% [markdown]
# Graphic:![BackEndLayers.png](data:image/png;base64,...)!

# %% [markdown]
# #### Artist Layer

# %% [markdown]
# Graphic:![ArtistLayers.png](data:image/png;base64,...)

# %% [markdown]
# #### Scripting Layer

# %% [markdown]
# Graphic:![ScriptingLayer.png](data:image/png;base64,...)

# %% [markdown]
# When discussing the architecture of softeware libraries, it is of great use to relate a conceptual overview to concrete software components. This is not only increases the inmediate knowledge with more definite context, but also provides a foundation for a quicker learning process uring future explorations. Let's examine the modules in the matplotlib Python package.

# %%
# This code is for clone the git repository we need into GoogleDrive folder
from google.colab import drive
import os

# Mount Google Drive
drive.mount('/content/drive')

# Define the repository and directory
repo_url = 'https://github.com/masteringmatplotlib/architecture'  # replace with your repository URL
dir_path = '/content/drive/MyDrive/Colab Notebooks/06_PyVisualization/01_MatPlotLib/01_DuMc_MAsPLT/git'  # replace with your Google Drive folder path

# Create the directory if it does not exist
os.makedirs(dir_path, exist_ok=True)

# Change the current working directory
os.chdir(dir_path)

# Clone the repository
# !git clone $repo_url
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# fatal: destination path 'architecture' already exists and is not an empty directory.

# %%
# !pip install pycallgraph2
# Out:
# ...
# Exception in thread Thread-5 (attachment_entry):
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/debugpy/server/api.py", line 237, in listen
#     sock, _ = endpoints_listener.accept()
#   File "/usr/lib/python3.10/socket.py", line 293, in accept
#     fd, addr = self._accept()
# TimeoutError: timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/google/colab/_debugpy.py", line 52, in attachment_entry
#     debugpy.listen(_dap_port)
#   File "/usr/local/lib/python3.10/dist-packages/debugpy/public_api.py", line 31, in wrapper
#     return wrapped(*args, **kwargs)
# ...

# %%
import matplotlib
matplotlib.use('nbagg')
# %matplotlib inline

# %%
# Create to sets of imports:

# For our dependencies
from glob import glob
from modulefinder import Module
from modulefinder import ModuleFinder
from os.path import dirname
from pprint import pprint
import sys
import trace
import urllib.request

# Modules specific for this notebook
import matplotlib.pyplot as plt
from IPython.core.display import Image
from pycallgraph2 import Config
from pycallgraph2 import GlobbingFilter
from pycallgraph2 import pycallgraph
from pycallgraph2.output import GraphvizOutput

# %%
# !pip install typecheck-decorator

# %%
# !pip install --upgrade typechecks

# %%
sys.path.append('/content/drive/MyDrive/Colab Notebooks/06_PyVisualization/01_MatPlotLib/01_DuMc_MAsPLT/git/architecture/lib')
from modarch import matplotlib_groupings
import modfind
import modgraph
from modutil import ls, rm
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-114b6e81c084> in <cell line: 3>()
#       1 sys.path.append('/content/drive/MyDrive/Colab Notebooks/06_PyVisualization/01_MatPlotLib/01_DuMc_MAsPLT/git/architecture/lib')
#       2 from modarch import matplotlib_groupings
# ----> 3 import modfind
#       4 import modgraph
#       5 from modutil import ls, rm
#
# /content/drive/MyDrive/Colab Notebooks/06_PyVisualization/01_MatPlotLib/01_DuMc_MAsPLT/git/architecture/lib/modfind.py in <module>
#       3 from collections.abc import Sequence
#       4
# ----> 5 from typecheck import typecheck
#       6 import typecheck as tc
#       7
#
# /usr/local/lib/python3.10/dist-packages/typecheck/__init__.py in <module>
#      10                         TypeCheckSpecificationError,
#      11                         optional, disable, enable)
# ...
